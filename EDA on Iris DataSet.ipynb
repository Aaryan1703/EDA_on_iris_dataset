# %%
#Continius vs continius
#continius vs catagorical
#catagorical vs catagorical

# cat con sepration
#for categorical data use value_counts() for this mainly use bar graph
#for continious data use sns library for this mainly use histogram
#types og graph: histogram, bar, boxplot,scatter ,heatmap, pairplot

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Aryan\\OneDrive\\Desktop\\DataSet\\iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
cat=list(df.columns[df.dtypes=="object"])
cat
# Out:
# ['species']

# %%
con=list(df.columns[df.dtypes!="object"])
con
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
df[con].describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %%
df[cat].describe().T
# Out:
#         count unique     top freq
# species   150      3  setosa   50

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df["species"].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
df["species"].value_counts().plot(kind="bar",title="Catagoriacal value graph")
# Out:
# <AxesSubplot: title={'center': 'Catagoriacal value graph'}>

# %%
for i in cat:
    df[i].value_counts().plot(kind="bar",title=i)

# %%
con
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
sns.histplot(data=df,x="sepal_length",kde=True)
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data=df,x="petal_width",kde=True)
# Out:
# <AxesSubplot: xlabel='petal_width', ylabel='Count'>

# %%
plt.figure(figsize=(10,10))
x=1
for i in con:
    plt.subplot(2,2,x)
    sns.histplot(data=df,x=i,kde=True)
    plt.title(f"histrogram for {i}")
    x=x+1
plt.show()

# %%
plt.scatter(df["sepal_length"],df["sepal_width"])
plt.xlabel("Sepal length")
plt.ylabel("sepal width")
plt.show()

# %%
plt.scatter(df["petal_length"],df["petal_width"])
plt.xlabel("petal width")
plt.ylabel("petal width")
plt.show()

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
plt.scatter(df["sepal_length"],df["petal_length"])

# %%
sns.heatmap(df.corr(),annot=True,fmt=".3f")
# Out:
# <AxesSubplot: >

# %%
cat
# Out:
# ['species']

# %%
con
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
sns.boxplot(data=df,x="species",y="petal_length")
# Out:
# <AxesSubplot: xlabel='species', ylabel='petal_length'>

# %%
plt.figure(figsize=(10,10))
x=1
for i in con:
    plt.subplot(2,2,x)
    sns.boxplot(data=df,x="species",y=i)
    x=x+1
    plt.title(f"boxplot for {i}")
plt.show()

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue="species")
